# %% [markdown]
# # Apertura del Dataframe

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Data.csv')
data.set_index('PisoApartamento', inplace=True)
data
# Out:
#                          Integrantes  Edad  Estatura(m)  Peso(kg)  \
# PisoApartamento
# 00 03                 Dylan Bastardo   0.6         0.80       6.0
# 00 03                 Fabio Bastardo  35.0         1.78      77.0
# 00 03               Indonesia Garcia  34.0         1.60      70.0
# 00 03                Leandro Alvarez  13.0         1.57      56.0
# 00 03                 Petra Bastardo  75.0         1.50      48.0
# ...                              ...   ...          ...       ...
# 14 03               Hayddy Hernandez  45.0         1.60      53.0
# 14 03                Yermahin Zamora  47.0         1.75      75.0
# 14 04              Michelle Melendez  21.0         1.51      63.0
# 14 04                 Thais Gonzales  49.0         1.50      60.0
# 14 04            Valentina Hernandez  16.0         1.54      68.0
#
#                  Padecimiento       Sexo Ocupacion
# PisoApartamento
# 00 03                 Ninguno  Masculino   Ninguno
# 00 03                 Ninguno  Masculino   Trabaja
# 00 03                 Ninguno   Femenino   Trabaja
# 00 03                 Ninguno  Masculino   Estudia
# 00 03            Hipertension   Femenino   Ninguno
# ...                       ...        ...       ...
# 14 03                    Asma   Femenino   Trabaja
# 14 03                 Ninguno  Masculino   Trabaja
# 14 04                 Ninguno   Femenino   Estudia
# 14 04                 Ninguno   Femenino   Trabaja
# 14 04                 Ninguno   Femenino   Estudia
#
# [101 rows x 7 columns]

# %% [markdown]
# # Medias por apartamento

# %%
# Media de cada valor (Estatura, peso, edades).
estatura_media = data.groupby('PisoApartamento')['Estatura(m)'].mean()
pesos_media = data.groupby('PisoApartamento')['Peso(kg)'].mean()
edades_media = data.groupby('PisoApartamento')['Edad'].mean()

# Graficos de barras.
plt.figure(figsize=(50, 15))
plt.subplot(331)
plt.bar(pesos_media.index, pesos_media.values, color = 'orange')
plt.xticks(size= 7, rotation= 50)
plt.title('Estadisticas de Media de Pesos')


plt.subplot(334)
plt.bar(estatura_media.index, estatura_media.values)
plt.xticks(size= 7, rotation= 50)
plt.title('Estadisticas de Media de Estatura')

plt.subplot(337)
plt.bar(edades_media.index, edades_media.values, color= 'green')
plt.xticks(size= 7, rotation= 50)
plt.title('Estadisticas de Media de Edades')

plt.show()

# %% [markdown]
# # Graficos de dispersión (edades, altura, peso)

# %%
indices_nounique = data.index.tolist() # Lista de indices completa

# Datos completos
pesos_completos = data['Peso(kg)'].tolist()
estaturas_completas = data['Estatura(m)'].tolist()
edades_completas = data['Edad'].tolist()

plt.figure(figsize=(17.5, 4.5)) # Tamaño de la figura

# Creación de los graficos dispersos detallados
plt.subplot(131)
plt.scatter(indices_nounique, pesos_completos, color = 'orange')
plt.title('Pesos', color = 'orange')
plt.xticks(size= 6, rotation= 50)

plt.subplot(132)
plt.scatter(indices_nounique, edades_completas, color = 'green')
plt.title('Edades', color= 'green')
plt.xticks(size= 6, rotation= 50)

plt.subplot(133)
plt.scatter(indices_nounique, estaturas_completas)
plt.title('Estatura', color= 'blue')
plt.xticks(size= 6, rotation= 50)

plt.suptitle('Estadisticas detalladas', color= 'red')

plt.show()

# %%
indices = data.index.unique().tolist() # Lista de indices unicas

plt.figure(figsize=(17.5, 4.5))

# Creación de los graficos dispersos medias
plt.subplot(131)
plt.scatter(indices, pesos_media.values, color = 'orange')
plt.title('Pesos', color = 'orange')
plt.xticks(size= 6, rotation= 50)

plt.subplot(132)
plt.scatter(indices, edades_media.values, color = 'green')
plt.title('Edades', color= 'green')
plt.xticks(size= 6, rotation= 50)

plt.subplot(133)
plt.scatter(indices, estatura_media.values)
plt.title('Estatura', color= 'blue')
plt.xticks(size= 6, rotation= 50)

plt.suptitle('Estadisticas medias', color= 'red')

plt.show()

# %% [markdown]
# # Estadisticas detalladas con grafico de caja

# %%
plt.figure(figsize=(17.5, 4.5))

# Creacion de estadisticas detalladas con grafico de caja
plt.subplot(131)
plt.boxplot(pesos_completos, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
plt.ylabel('Pesos', color = 'orange')


plt.subplot(132)
plt.boxplot(edades_completas, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
plt.ylabel('Edades', color= 'green')

plt.subplot(133)
plt.boxplot(estaturas_completas, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
plt.ylabel('Estatura', color= 'blue')

plt.supylabels('Estadisticas detalladas', color= 'red')

plt.show()
# Out:
# C:\Users\cpustorevzla\AppData\Local\Temp\ipykernel_18752\624285413.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(pesos_completos, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
# C:\Users\cpustorevzla\AppData\Local\Temp\ipykernel_18752\624285413.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(edades_completas, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
# C:\Users\cpustorevzla\AppData\Local\Temp\ipykernel_18752\624285413.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(estaturas_completas, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 17
#      14 plt.boxplot(estaturas_completas, labels = ['Apartamentos'], flierprops=dict(markerfacecolor='red'))
#      15 plt.ylabel('Estatura', color= 'blue')
# ---> 17 plt.supylabels('Estadisticas detalladas', color= 'red')
#      19 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'supylabels'
